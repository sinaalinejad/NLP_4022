# %% [markdown]
# # Q2

# %% [markdown]
# *   In this question we will Build a bigram HMM tagger.
# *   First we split the part-of-speech-tagged corpus into a training set and test set.
# *   From the labeled training set, we train the transition and observation probabilities of the HMM tagger directly on the hand-tagged data.
# *   Then implement the Viterbi algorithm so we can decode a test sentence.
# *   Run the algorithm on the test set. Report its error rate and
# compare its performance to the most frequent tag baseline.
# *   Build a confusion matrix and investigate the most frequent errors.

# %%
import nltk
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to C:\Users\Sina
# [nltk_data]     Alinejad\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\universal_tagset.zip.
# True

# %%
import math
import nltk
nltk.download('brown')
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to C:\Users\Sina
# [nltk_data]     Alinejad\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
def collect_probabilities(_samples):
    """
    Collects various probabilities and frequencies required for Hidden Markov Model (HMM) training based on given samples.

    Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing training data.

    Returns:
    tuple: A tuple containing four dictionaries:
           - tag_freq: A dictionary storing the frequency of each tag type.
           - word_per_tag_freq: A nested dictionary storing the frequency of each word under each tag.
           - bigram: A nested dictionary representing the bigram probabilities between tag types.
           - pi: A dictionary storing the initial probability distributions for tag types.

    Comments:
    - tag_freq: Stores the frequency of each tag type observed in the training data.
    - word_per_tag_freq: Stores the frequency of each word observed under each tag in the training data.
      - Each word under a specific tag is initialized with a count of 2 to provide initial smoothing.
    - bigram: Represents the transition probabilities between tag types based on bigram counts.
    - pi: Stores the initial probability distributions for tag types based on the second tag in each sample.
    """
    tag_freq = {}
    word_per_tag_freq = {}
    bigram = {}
    pi = {}
    samples_len = len(_samples)

    # Iterate through samples to collect tag frequencies, word frequencies under each tag, and initial probabilities
    for i in range(samples_len):
        sample = _samples[i]
        has_next = i + 1 < samples_len

        # Collect data for initial probabilities (pi)
        if has_next:
            if _samples[i + 1][1] not in pi:
                pi.update({_samples[i + 1][1]: 2})
            else:
                pi[_samples[i + 1][1]] += 1  # Increment count for subsequent occurrences

        # Count tag frequencies (tag_freq) and word frequencies under each tag (word_per_tag_freq)
        if sample[1] not in tag_freq:
            tag_freq.update({sample[1]: 2})
            word_per_tag_freq.update({sample[1]: {sample[0]: 2}})
        else:
            tag_freq[sample[1]] += 1
            if sample[0] not in word_per_tag_freq[sample[1]]:
                word_per_tag_freq[sample[1]].update({sample[0]: 2})
            else:
                word_per_tag_freq[sample[1]][sample[0]] += 1

    # Initialize the bigram matrix with default counts
    for tag_0 in tag_freq:
        bigram.update({tag_0: {}})
        for tag_1 in tag_freq:
            bigram[tag_0].update({tag_1: 1})

    # Count bigram occurrences
    for i in range(samples_len - 1):
        current_tag, next_tag = _samples[i][1], _samples[i + 1][1]
        bigram[current_tag][next_tag] += 1  # Increment count for observed bigram

    # Return collected probabilities and frequencies
    return tag_freq, word_per_tag_freq, bigram, pi

# %%
def create_confusion_matrix(predictions, hidden_state, confusion_matrices, is_correct):
  """
  Updates the confusion matrices based on the predictions and hidden states,
  calculates the number of correct predictions, and identifies tags with
  the most false positives and false negatives.

  Args:
    predictions (list): Predicted sequence of tags for the given input data.
    hidden_state (list): Actual sequence of tags for the given input data.
    confusion_matrices (dict): A dictionary containing confusion matrices for each tag.
    is_correct (int): Counter for the number of correct predictions.

  Returns:
    int: Updated count of correct predictions after processing the input data.

  Comments:
    - As the Viterbi algorithm processes each sentence in the test data,
      it compares the predicted tags against the actual tags for each word in the sentence.
      - For each word in the sentence:
          - If the predicted tag matches the actual tag (a true positive),
            the corresponding count in the confusion matrix for that tag is incremented.
          - If the predicted tag does not match the actual tag:
              - If the predicted tag is incorrect (a false positive), the FP count for
                the predicted tag is incremented, and the TN counts for other tags are incremented.
              - If the actual tag is not predicted (a false negative), the FN count for the actual
                tag is incremented, and the TN counts for other tags are incremented.
    - After updating the confusion matrices, the function identifies tags with
      the highest counts of false positives and false negatives.
  """
  # fill in the confusion matrix
  for i in range(len(predictions)):
    if predictions[i] == hidden_state[i]:
      # prediction is correct
      is_correct += 1
      confusion_matrices[predictions[i]]['TP'] += 1  # Increment True Positive for predicted tag
      for j in confusion_matrices:
        if j != predictions[i]:
          confusion_matrices[j]['TN'] += 1  # Increment True Negative for other tags
    else:
      # prediction is incorrect
      confusion_matrices[predictions[i]]['FP'] += 1  # Increment False Positive for predicted tag
      confusion_matrices[hidden_state[i]]['FN'] += 1  # Increment False Negative for actual tag
      for j in confusion_matrices:
        if j != predictions[i] and j != hidden_state[i]:
          confusion_matrices[j]['TN'] += 1  # Increment True Negative for other tags

  # rank
  highest_FP_tag = []
  highest_FP = -1
  highest_FN_tag = []
  highest_FN = -1

  for tag in confusion_matrices:
    print(f'{tag}: {confusion_matrices[tag]}')

    if confusion_matrices[tag]['FP'] > highest_FP:
      highest_FP = confusion_matrices[tag]['FP']
      highest_FP_tag = tag

    if confusion_matrices[tag]['FN'] > highest_FN:
      highest_FN = confusion_matrices[tag]['FN']
      highest_FN_tag = tag

  print(f'\nTag with the most false positives is: {highest_FP_tag} with {highest_FP} counts.')
  print(f'Tag with the most false negative is:  {highest_FN_tag} with {highest_FN} counts.')

  return is_correct

# %%
def viterbi(_samples, _tag_freq, _word_per_tag_freq, _bigram, _init_dist):
  """
  Performs the Viterbi algorithm for part-of-speech tagging on a given test set of sentences.

  Args:
    _samples (list): A list of tuples containing (word, tag) pairs representing the test data.
    _tag_freq (dict): A dictionary storing the frequency of each tag type observed in the training data.
    _word_per_tag_freq (dict): A nested dictionary storing the frequency of each word observed under each tag in the training data.
    _bigram (dict): A nested dictionary representing the bigram probabilities between tag types.
    _init_dist (dict): A dictionary storing the initial probability distributions for tag types.

  Comments:
    - This function implements the Viterbi algorithm for part-of-speech tagging.
    - It processes each sentence in the test set, using '.' as an indicator that a sentence is over.
    - The function populates a confusion matrix to track the performance of the model.
    - The Viterbi algorithm is used to find the most likely sequence of tags for each sentence.
    - The algorithm iterates through each word in the sentence, calculating the most likely tag sequence based on probabilities and transition probabilities.
    - The model's predictions are compared against the actual tags to evaluate accuracy and populate the confusion matrix.
    - The function prints detailed information about predictions, including the sentence, hidden states, and predicted tags.
    - It also identifies tags with the most false positives and false negatives based on the confusion matrix.
    - Finally, the function prints the overall accuracy of the model on the test set.
  """
  test_size = len(_samples)
  current_index = 0
  is_correct = 0

  # populate the confusion matrix
  confusion_matrices = {}
  for tag in _tag_freq:
    confusion_matrices.update({tag: {'TP': 0, 'FP': 0, 'TN': 0, 'FN': 0}})

  while current_index < test_size:
    # find the boundry of a sentence
    sentence = []
    hidden_state = []
    last_token = ''
    while last_token != '.' and current_index < test_size:
      sentence.append(_samples[current_index][0])  # Word from sample
      hidden_state.append(_samples[current_index][1])  # Tag from sample
      last_token = sentence[-1]
      current_index += 1

    # initialization step
    path_probability = {}
    backpointer = {}
    for tag in _init_dist:
      path_probability.update({tag: []})
      backpointer.update({tag: [0]})

      # initial distribution of this tag
      pi_tag = _init_dist[tag]

      # b_word is the probability of the word being generated by this tag
      if sentence[0] in _word_per_tag_freq[tag]:
        b_word = _word_per_tag_freq[tag][sentence[0]] / (_tag_freq[tag] + len(_word_per_tag_freq))  # Smoothed probability
      else:
        b_word = 2.2250738585072014e-100

      path_probability[tag].append(math.log(pi_tag * b_word, 10))  # Log probability

    # recursion step
    T = len(sentence)
    for i in range(1, T):
      for tag in _init_dist:
        if sentence[i] in _word_per_tag_freq[tag]:
          b_word = _word_per_tag_freq[tag][sentence[i]] / (_tag_freq[tag] + len(_word_per_tag_freq))
        else:
          b_word = 2.2250738585072014e-100

        # search the maximum value of
        # viterbi[s', t-1] * a(s|s') *b_s(o_t)
        best_trans_prob = -float('inf')  # Negative infinity for log probability
        best_trans_tag = ''
        for prev_tag in _init_dist:
          if prev_tag in _bigram and tag in _bigram[prev_tag]:
            transitional_prob = _bigram[prev_tag][tag] / (_tag_freq[prev_tag])  # Smoothed probability
          else:
            transitional_prob = 2.2250738585072014e-100

          prob = path_probability[prev_tag][i - 1] + math.log(transitional_prob * b_word, 10)

          if prob > best_trans_prob:
            best_trans_prob = prob
            best_trans_tag = prev_tag

        path_probability[tag].append(best_trans_prob)
        backpointer[tag].append(best_trans_tag)

    # termination step
    best_path_prob = -float('inf')
    best_path_pointer = None
    for tag in _init_dist:
      if path_probability[tag][-1] > best_path_prob:
        best_path_prob = path_probability[tag][-1]
        best_path_pointer = tag

    # make the predictions path
    predictions = [best_path_pointer]
    for i in reversed(range(1, T)):
      predictions.append(backpointer[predictions[0]][i])
      predictions[0] = backpointer[predictions[0]][i]

    predictions.reverse()

    print(f'sentence:       {sentence}')
    print(f'hidden s:       {hidden_state}')
    print(f'predictions:    {predictions}')

    is_correct = create_confusion_matrix(predictions, hidden_state, confusion_matrices, is_correct)

  print(f'\nmodel got {is_correct} samples correct out of {test_size}')
  print(f'accuracy: {is_correct / test_size}')

# %%
CORPUS = brown.tagged_words(categories='news', tagset='universal')
CORPUS_SIZE = len(brown.tagged_words(categories='news'))

CUT_OFF = math.floor(CORPUS_SIZE * 0.75)

# section off training and testing lists from corpus
training_list = CORPUS[:CUT_OFF]
testing_list = CORPUS[CUT_OFF:]

tag_frequency, word_per_tag_frequency, tag_bigram, init_dist = collect_probabilities(training_list)
viterbi(testing_list, tag_frequency, word_per_tag_frequency, tag_bigram, init_dist)
# Out:
# sentence:       ['these', 'could', 'not', 'be', 'talked', 'away', 'at', 'a', 'heads', 'of', 'government', 'meeting', '.']
# hidden s:       ['DET', 'VERB', 'ADV', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'VERB', 'ADV', 'VERB', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'ADP', 'NOUN', 'NOUN', 'DET']
# DET: {'TP': 2, 'FP': 1, 'TN': 10, 'FN': 0}
# NOUN: {'TP': 2, 'FP': 0, 'TN': 10, 'FN': 1}
# ADJ: {'TP': 0, 'FP': 0, 'TN': 13, 'FN': 0}
# VERB: {'TP': 3, 'FP': 1, 'TN': 9, 'FN': 0}
# ADP: {'TP': 2, 'FP': 0, 'TN': 11, 'FN': 0}
# .: {'TP': 0, 'FP': 0, 'TN': 12, 'FN': 1}
# ADV: {'TP': 2, 'FP': 0, 'TN': 11, 'FN': 0}
# CONJ: {'TP': 0, 'FP': 0, 'TN': 13, 'FN': 0}
# PRT: {'TP': 0, 'FP': 0, 'TN': 13, 'FN': 0}
# PRON: {'TP': 0, 'FP': 0, 'TN': 13, 'FN': 0}
# NUM: {'TP': 0, 'FP': 0, 'TN': 13, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 13, 'FN': 0}
#
# Tag with the most false positives is: DET with 1 counts.
# Tag with the most false negative is:  NOUN with 1 counts.
# sentence:       ['He', 'wanted', 'to', 'buy', 'time', 'to', 'strengthen', 'the', 'U.', 'S.', 'and', 'its', 'allies', 'and', 'to', 'define', 'and', 'begin', 'to', 'implement', 'his', 'foreign', 'policy', '.']
# hidden s:       ['PRON', 'VERB', 'PRT', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'CONJ', 'DET', 'NOUN', 'CONJ', 'PRT', 'VERB', 'CONJ', 'VERB', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'PRT', 'VERB', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'CONJ', 'DET', 'NOUN', 'CONJ', 'PRT', 'VERB', 'CONJ', 'VERB', 'PRT', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRON']
# DET: {'TP': 5, 'FP': 1, 'TN': 31, 'FN': 0}
# NOUN: {'TP': 7, 'FP': 0, 'TN': 29, 'FN': 1}
# ADJ: {'TP': 1, 'FP': 0, 'TN': 36, 'FN': 0}
# VERB: {'TP': 9, 'FP': 1, 'TN': 27, 'FN': 0}
# ADP: {'TP': 2, 'FP': 0, 'TN': 35, 'FN': 0}
# .: {'TP': 0, 'FP': 0, 'TN': 35, 'FN': 2}
# ADV: {'TP': 2, 'FP': 0, 'TN': 35, 'FN': 0}
# CONJ: {'TP': 3, 'FP': 0, 'TN': 34, 'FN': 0}
# PRT: {'TP': 4, 'FP': 0, 'TN': 33, 'FN': 0}
# PRON: {'TP': 1, 'FP': 1, 'TN': 35, 'FN': 0}
# NUM: {'TP': 0, 'FP': 0, 'TN': 37, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 37, 'FN': 0}
#
# Tag with the most false positives is: DET with 1 counts.
# Tag with the most false negative is:  . with 2 counts.
# sentence:       ['Last', 'Friday', 'the', 'White', 'House', 'announced', ':', 'President', 'Kennedy', 'will', 'meet', 'with', 'Soviet', 'Premier', 'Nikita', 'S.', 'Khrushchev', 'in', 'Vienna', 'June', '3', 'and', '4', '.']
# hidden s:       ['ADJ', 'NOUN', 'DET', 'ADJ', 'NOUN', 'VERB', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NUM', 'CONJ', 'NUM', '.']
# predictions:    ['ADJ', 'NOUN', 'DET', 'ADJ', 'NOUN', 'VERB', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NUM', 'CONJ', 'NUM', 'ADJ']
# DET: {'TP': 6, 'FP': 1, 'TN': 54, 'FN': 0}
# NOUN: {'TP': 18, 'FP': 0, 'TN': 42, 'FN': 1}
# ADJ: {'TP': 3, 'FP': 1, 'TN': 57, 'FN': 0}
# VERB: {'TP': 12, 'FP': 1, 'TN': 48, 'FN': 0}
# ADP: {'TP': 4, 'FP': 0, 'TN': 57, 'FN': 0}
# .: {'TP': 1, 'FP': 0, 'TN': 57, 'FN': 3}
# ADV: {'TP': 2, 'FP': 0, 'TN': 59, 'FN': 0}
# CONJ: {'TP': 4, 'FP': 0, 'TN': 57, 'FN': 0}
# PRT: {'TP': 4, 'FP': 0, 'TN': 57, 'FN': 0}
# PRON: {'TP': 1, 'FP': 1, 'TN': 59, 'FN': 0}
# NUM: {'TP': 2, 'FP': 0, 'TN': 59, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 61, 'FN': 0}
#
# Tag with the most false positives is: DET with 1 counts.
# Tag with the most false negative is:  . with 3 counts.
# sentence:       ['The', 'announcement', 'came', 'after', 'a', 'period', 'of', 'sharp', 'deterioration', 'in', 'East-West', 'relations', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'DET']
# DET: {'TP': 8, 'FP': 2, 'TN': 64, 'FN': 0}
# NOUN: {'TP': 22, 'FP': 0, 'TN': 51, 'FN': 1}
# ADJ: {'TP': 5, 'FP': 1, 'TN': 68, 'FN': 0}
# VERB: {'TP': 13, 'FP': 1, 'TN': 60, 'FN': 0}
# ADP: {'TP': 7, 'FP': 0, 'TN': 67, 'FN': 0}
# .: {'TP': 1, 'FP': 0, 'TN': 69, 'FN': 4}
# ADV: {'TP': 2, 'FP': 0, 'TN': 72, 'FN': 0}
# CONJ: {'TP': 4, 'FP': 0, 'TN': 70, 'FN': 0}
# PRT: {'TP': 4, 'FP': 0, 'TN': 70, 'FN': 0}
# PRON: {'TP': 1, 'FP': 1, 'TN': 72, 'FN': 0}
# NUM: {'TP': 2, 'FP': 0, 'TN': 72, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 74, 'FN': 0}
#
# Tag with the most false positives is: DET with 2 counts.
# Tag with the most false negative is:  . with 4 counts.
# sentence:       ['The', 'heightened', 'tension', ',', 'in', 'fact', ',', 'had', 'been', 'a', 'major', 'factor', 'in', 'the', "President's", 'change', 'of', 'view', 'about', 'the', 'urgency', 'of', 'a', 'meeting', 'with', 'the', 'Soviet', 'leader', '.']
# hidden s:       ['DET', 'VERB', 'NOUN', '.', 'ADP', 'NOUN', '.', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', '.', 'ADP', 'NOUN', '.', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'DET']
# DET: {'TP': 14, 'FP': 3, 'TN': 86, 'FN': 0}
# NOUN: {'TP': 32, 'FP': 1, 'TN': 69, 'FN': 1}
# ADJ: {'TP': 6, 'FP': 1, 'TN': 96, 'FN': 0}
# VERB: {'TP': 15, 'FP': 1, 'TN': 86, 'FN': 1}
# ADP: {'TP': 13, 'FP': 0, 'TN': 90, 'FN': 0}
# .: {'TP': 3, 'FP': 0, 'TN': 95, 'FN': 5}
# ADV: {'TP': 2, 'FP': 0, 'TN': 101, 'FN': 0}
# CONJ: {'TP': 4, 'FP': 0, 'TN': 99, 'FN': 0}
# PRT: {'TP': 4, 'FP': 0, 'TN': 99, 'FN': 0}
# PRON: {'TP': 1, 'FP': 1, 'TN': 101, 'FN': 0}
# NUM: {'TP': 2, 'FP': 0, 'TN': 101, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 103, 'FN': 0}
#
# Tag with the most false positives is: DET with 3 counts.
# Tag with the most false negative is:  . with 5 counts.
# sentence:       ['He', 'was', 'not', 'going', 'to', 'Vienna', 'to', 'negotiate', '--', 'the', 'simultaneous', 'announcements', 'in', 'Washington', 'and', 'Moscow', 'last', 'week', 'stressed', 'that', 'no', 'formal', 'negotiations', 'were', 'planned', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'VERB', 'ADP', 'NOUN', 'PRT', 'VERB', '.', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'VERB', 'ADP', 'NOUN', 'PRT', 'VERB', '.', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'CONJ', 'NOUN', 'ADJ', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', 'PRON']
# DET: {'TP': 16, 'FP': 3, 'TN': 110, 'FN': 0}
# NOUN: {'TP': 38, 'FP': 1, 'TN': 89, 'FN': 1}
# ADJ: {'TP': 9, 'FP': 1, 'TN': 119, 'FN': 0}
# VERB: {'TP': 21, 'FP': 1, 'TN': 106, 'FN': 1}
# ADP: {'TP': 16, 'FP': 0, 'TN': 113, 'FN': 0}
# .: {'TP': 4, 'FP': 0, 'TN': 119, 'FN': 6}
# ADV: {'TP': 3, 'FP': 0, 'TN': 126, 'FN': 0}
# CONJ: {'TP': 5, 'FP': 0, 'TN': 124, 'FN': 0}
# PRT: {'TP': 5, 'FP': 0, 'TN': 124, 'FN': 0}
# PRON: {'TP': 2, 'FP': 2, 'TN': 125, 'FN': 0}
# NUM: {'TP': 2, 'FP': 0, 'TN': 127, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 129, 'FN': 0}
#
# Tag with the most false positives is: DET with 3 counts.
# Tag with the most false negative is:  . with 6 counts.
# sentence:       ['But', 'Mr.', 'Kennedy', 'had', 'become', 'convinced', 'that', 'a', 'personal', 'confrontation', 'with', 'Mr.', 'Khrushchev', 'might', 'be', 'the', 'only', 'way', 'to', 'prevent', 'catastrophe', '.']
# hidden s:       ['CONJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', '.']
# predictions:    ['CONJ', 'NOUN', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRT', 'VERB', 'NOUN', 'CONJ']
# DET: {'TP': 18, 'FP': 3, 'TN': 130, 'FN': 0}
# NOUN: {'TP': 45, 'FP': 1, 'TN': 104, 'FN': 1}
# ADJ: {'TP': 11, 'FP': 1, 'TN': 139, 'FN': 0}
# VERB: {'TP': 27, 'FP': 1, 'TN': 122, 'FN': 1}
# ADP: {'TP': 18, 'FP': 0, 'TN': 133, 'FN': 0}
# .: {'TP': 4, 'FP': 0, 'TN': 140, 'FN': 7}
# ADV: {'TP': 3, 'FP': 0, 'TN': 148, 'FN': 0}
# CONJ: {'TP': 6, 'FP': 1, 'TN': 144, 'FN': 0}
# PRT: {'TP': 6, 'FP': 0, 'TN': 145, 'FN': 0}
# PRON: {'TP': 2, 'FP': 2, 'TN': 147, 'FN': 0}
# NUM: {'TP': 2, 'FP': 0, 'TN': 149, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 151, 'FN': 0}
#
# Tag with the most false positives is: DET with 3 counts.
# Tag with the most false negative is:  . with 7 counts.
# sentence:       ['That', 'objective', 'set', 'the', 'high', 'stakes', 'and', 'drama', 'of', 'the', 'Vienna', 'meeting', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'DET']
# DET: {'TP': 21, 'FP': 4, 'TN': 139, 'FN': 0}
# NOUN: {'TP': 50, 'FP': 1, 'TN': 112, 'FN': 1}
# ADJ: {'TP': 12, 'FP': 1, 'TN': 151, 'FN': 0}
# VERB: {'TP': 28, 'FP': 1, 'TN': 134, 'FN': 1}
# ADP: {'TP': 19, 'FP': 0, 'TN': 145, 'FN': 0}
# .: {'TP': 4, 'FP': 0, 'TN': 152, 'FN': 8}
# ADV: {'TP': 3, 'FP': 0, 'TN': 161, 'FN': 0}
# CONJ: {'TP': 7, 'FP': 1, 'TN': 156, 'FN': 0}
# PRT: {'TP': 6, 'FP': 0, 'TN': 158, 'FN': 0}
# PRON: {'TP': 2, 'FP': 2, 'TN': 160, 'FN': 0}
# NUM: {'TP': 2, 'FP': 0, 'TN': 162, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 164, 'FN': 0}
#
# Tag with the most false positives is: DET with 4 counts.
# Tag with the most false negative is:  . with 8 counts.
# sentence:       ['Despite', 'efforts', 'by', 'Washington', 'last', 'week', 'to', 'play', 'down', 'the', 'significance', 'of', 'the', 'meeting', ',', 'it', 'clearly', 'was', 'going', 'to', 'be', 'one', 'of', 'the', 'crucial', 'encounters', 'of', 'the', 'cold', 'war', '.']
# hidden s:       ['ADP', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'NOUN', 'PRT', 'VERB', 'PRT', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'ADP', 'NOUN', 'ADJ', 'NOUN', 'PRT', 'VERB', 'PRT', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'PRON', 'ADV', 'VERB', 'VERB', 'PRT', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP']
# DET: {'TP': 25, 'FP': 4, 'TN': 166, 'FN': 0}
# NOUN: {'TP': 57, 'FP': 1, 'TN': 136, 'FN': 1}
# ADJ: {'TP': 15, 'FP': 1, 'TN': 179, 'FN': 0}
# VERB: {'TP': 32, 'FP': 1, 'TN': 161, 'FN': 1}
# ADP: {'TP': 24, 'FP': 1, 'TN': 170, 'FN': 0}
# .: {'TP': 5, 'FP': 0, 'TN': 181, 'FN': 9}
# ADV: {'TP': 4, 'FP': 0, 'TN': 191, 'FN': 0}
# CONJ: {'TP': 7, 'FP': 1, 'TN': 187, 'FN': 0}
# PRT: {'TP': 9, 'FP': 0, 'TN': 186, 'FN': 0}
# PRON: {'TP': 3, 'FP': 2, 'TN': 190, 'FN': 0}
# NUM: {'TP': 3, 'FP': 0, 'TN': 192, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 195, 'FN': 0}
#
# Tag with the most false positives is: DET with 4 counts.
# Tag with the most false negative is:  . with 9 counts.
# sentence:       ['Road', 'to', 'Vienna', 'The', 'U.', 'S.', 'and', 'Soviet', 'heads', 'of', 'Government', 'have', 'met', 'three', 'times', 'since', 'Sir', 'Winston', 'Churchill', 'in', '1953', 'introduced', 'a', 'new', 'word', 'into', 'international', 'diplomacy', 'with', 'his', 'call', 'for', 'a', 'fresh', 'approach', 'to', 'the', 'problem', 'of', 'peace', '``', 'at', 'the', 'summit', 'of', 'the', 'nations', "''", '.']
# hidden s:       ['NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NUM', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.']
# predictions:    ['NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'ADP', 'NOUN', 'VERB', 'VERB', 'NUM', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NUM', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN']
# DET: {'TP': 32, 'FP': 4, 'TN': 208, 'FN': 0}
# NOUN: {'TP': 75, 'FP': 2, 'TN': 165, 'FN': 2}
# ADJ: {'TP': 18, 'FP': 1, 'TN': 225, 'FN': 0}
# VERB: {'TP': 35, 'FP': 2, 'TN': 206, 'FN': 1}
# ADP: {'TP': 35, 'FP': 1, 'TN': 208, 'FN': 0}
# .: {'TP': 7, 'FP': 0, 'TN': 227, 'FN': 10}
# ADV: {'TP': 4, 'FP': 0, 'TN': 240, 'FN': 0}
# CONJ: {'TP': 8, 'FP': 1, 'TN': 235, 'FN': 0}
# PRT: {'TP': 9, 'FP': 0, 'TN': 235, 'FN': 0}
# PRON: {'TP': 3, 'FP': 2, 'TN': 239, 'FN': 0}
# NUM: {'TP': 5, 'FP': 0, 'TN': 239, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 244, 'FN': 0}
#
# Tag with the most false positives is: DET with 4 counts.
# Tag with the most false negative is:  . with 10 counts.
# sentence:       ['The', 'first', 'time', 'was', 'in', '1955', 'when', 'a', 'full-dress', 'Big', 'Four', 'summit', 'meeting', 'produced', 'the', '``', 'spirit', 'of', 'Geneva', "''", '.']
# hidden s:       ['DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'NUM', 'ADV', 'DET', 'NOUN', 'ADJ', 'NUM', 'NOUN', 'NOUN', 'VERB', 'DET', '.', 'NOUN', 'ADP', 'NOUN', '.', '.']
# predictions:    ['DET', 'ADJ', 'NOUN', 'VERB', 'ADP', 'NUM', 'ADV', 'DET', 'ADJ', 'ADJ', 'NUM', 'NOUN', 'NOUN', 'VERB', 'DET', '.', 'NOUN', 'ADP', 'NOUN', '.', 'DET']
# DET: {'TP': 35, 'FP': 5, 'TN': 225, 'FN': 0}
# NOUN: {'TP': 80, 'FP': 2, 'TN': 180, 'FN': 3}
# ADJ: {'TP': 20, 'FP': 2, 'TN': 243, 'FN': 0}
# VERB: {'TP': 37, 'FP': 2, 'TN': 225, 'FN': 1}
# ADP: {'TP': 37, 'FP': 1, 'TN': 227, 'FN': 0}
# .: {'TP': 9, 'FP': 0, 'TN': 245, 'FN': 11}
# ADV: {'TP': 5, 'FP': 0, 'TN': 260, 'FN': 0}
# CONJ: {'TP': 8, 'FP': 1, 'TN': 256, 'FN': 0}
# PRT: {'TP': 9, 'FP': 0, 'TN': 256, 'FN': 0}
# PRON: {'TP': 3, 'FP': 2, 'TN': 260, 'FN': 0}
# NUM: {'TP': 7, 'FP': 0, 'TN': 258, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 265, 'FN': 0}
#
# Tag with the most false positives is: DET with 5 counts.
# Tag with the most false negative is:  . with 11 counts.
# sentence:       ['The', 'spirit', 'served', 'chiefly', 'to', 'lull', 'the', 'West', 'while', 'Moscow', 'made', 'inroads', 'into', 'the', 'Middle', 'East', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'ADJ', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'DET']
# DET: {'TP': 38, 'FP': 6, 'TN': 238, 'FN': 0}
# NOUN: {'TP': 83, 'FP': 2, 'TN': 192, 'FN': 5}
# ADJ: {'TP': 21, 'FP': 3, 'TN': 258, 'FN': 0}
# VERB: {'TP': 40, 'FP': 3, 'TN': 238, 'FN': 1}
# ADP: {'TP': 39, 'FP': 1, 'TN': 242, 'FN': 0}
# .: {'TP': 9, 'FP': 0, 'TN': 261, 'FN': 12}
# ADV: {'TP': 6, 'FP': 0, 'TN': 276, 'FN': 0}
# CONJ: {'TP': 8, 'FP': 1, 'TN': 273, 'FN': 0}
# PRT: {'TP': 10, 'FP': 0, 'TN': 272, 'FN': 0}
# PRON: {'TP': 3, 'FP': 2, 'TN': 277, 'FN': 0}
# NUM: {'TP': 7, 'FP': 0, 'TN': 275, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 282, 'FN': 0}
#
# Tag with the most false positives is: DET with 6 counts.
# Tag with the most false negative is:  . with 12 counts.
# sentence:       ['In', '1959', 'President', 'Eisenhower', 'and', 'Premier', 'Khrushchev', 'held', 'an', 'informal', 'session', 'in', 'the', 'U.', 'S.', '.']
# hidden s:       ['ADP', 'NUM', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['ADP', 'NUM', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP']
# DET: {'TP': 40, 'FP': 6, 'TN': 252, 'FN': 0}
# NOUN: {'TP': 90, 'FP': 3, 'TN': 200, 'FN': 5}
# ADJ: {'TP': 21, 'FP': 3, 'TN': 273, 'FN': 1}
# VERB: {'TP': 41, 'FP': 3, 'TN': 253, 'FN': 1}
# ADP: {'TP': 41, 'FP': 2, 'TN': 255, 'FN': 0}
# .: {'TP': 9, 'FP': 0, 'TN': 276, 'FN': 13}
# ADV: {'TP': 6, 'FP': 0, 'TN': 292, 'FN': 0}
# CONJ: {'TP': 9, 'FP': 1, 'TN': 288, 'FN': 0}
# PRT: {'TP': 10, 'FP': 0, 'TN': 288, 'FN': 0}
# PRON: {'TP': 3, 'FP': 2, 'TN': 293, 'FN': 0}
# NUM: {'TP': 8, 'FP': 0, 'TN': 290, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 298, 'FN': 0}
#
# Tag with the most false positives is: DET with 6 counts.
# Tag with the most false negative is:  . with 13 counts.
# sentence:       ['That', 'meeting', 'produced', 'the', '``', 'spirit', 'of', 'Camp', 'David', "''", '--', 'a', 'spirit', ',', 'it', 'later', 'turned', 'out', ',', 'that', 'masked', 'a', 'basic', 'misunderstanding', 'about', 'progress', 'toward', 'a', 'Berlin', 'settlement', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'DET', '.', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', '.', 'DET', 'NOUN', '.', 'PRON', 'ADV', 'VERB', 'PRT', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'DET', '.', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'DET', 'NOUN', '.', 'PRON', 'ADV', 'VERB', 'PRT', '.', 'PRON', 'VERB', 'DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'DET']
# DET: {'TP': 45, 'FP': 8, 'TN': 276, 'FN': 0}
# NOUN: {'TP': 98, 'FP': 3, 'TN': 222, 'FN': 6}
# ADJ: {'TP': 22, 'FP': 3, 'TN': 303, 'FN': 1}
# VERB: {'TP': 44, 'FP': 3, 'TN': 281, 'FN': 1}
# ADP: {'TP': 44, 'FP': 2, 'TN': 283, 'FN': 0}
# .: {'TP': 14, 'FP': 0, 'TN': 301, 'FN': 14}
# ADV: {'TP': 7, 'FP': 0, 'TN': 322, 'FN': 0}
# CONJ: {'TP': 9, 'FP': 1, 'TN': 319, 'FN': 0}
# PRT: {'TP': 11, 'FP': 0, 'TN': 318, 'FN': 0}
# PRON: {'TP': 5, 'FP': 2, 'TN': 322, 'FN': 0}
# NUM: {'TP': 8, 'FP': 0, 'TN': 321, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 329, 'FN': 0}
#
# Tag with the most false positives is: DET with 8 counts.
# Tag with the most false negative is:  . with 14 counts.
# sentence:       ['On', 'the', 'third', 'occasion', '--', 'another', 'Big', 'Four', 'summit', 'session', 'at', 'Paris', 'a', 'year', 'ago', '--', 'there', 'was', 'no', 'problem', 'of', 'an', 'illusory', '``', 'spirit', "''", '.']
# hidden s:       ['ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'ADJ', 'NUM', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADV', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', '.', 'NOUN', '.', '.']
# predictions:    ['ADP', 'DET', 'ADJ', 'NOUN', '.', 'DET', 'ADJ', 'NUM', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADV', '.', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', '.', 'ADP']
# DET: {'TP': 50, 'FP': 8, 'TN': 298, 'FN': 0}
# NOUN: {'TP': 105, 'FP': 4, 'TN': 241, 'FN': 6}
# ADJ: {'TP': 24, 'FP': 3, 'TN': 327, 'FN': 2}
# VERB: {'TP': 45, 'FP': 3, 'TN': 307, 'FN': 1}
# ADP: {'TP': 47, 'FP': 3, 'TN': 306, 'FN': 0}
# .: {'TP': 18, 'FP': 0, 'TN': 323, 'FN': 15}
# ADV: {'TP': 8, 'FP': 0, 'TN': 348, 'FN': 0}
# CONJ: {'TP': 9, 'FP': 1, 'TN': 346, 'FN': 0}
# PRT: {'TP': 12, 'FP': 0, 'TN': 344, 'FN': 0}
# PRON: {'TP': 5, 'FP': 2, 'TN': 349, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 347, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 356, 'FN': 0}
#
# Tag with the most false positives is: DET with 8 counts.
# Tag with the most false negative is:  . with 15 counts.
# sentence:       ['Premier', 'Khrushchev', 'wrecked', 'the', 'conference', 'at', 'its', 'initial', 'session', 'with', 'a', 'bitter', 'denunciation', 'of', 'the', 'U.', 'S.', 'for', 'the', 'U-2', 'incident', '.']
# hidden s:       ['NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN']
# DET: {'TP': 55, 'FP': 8, 'TN': 315, 'FN': 0}
# NOUN: {'TP': 114, 'FP': 5, 'TN': 253, 'FN': 6}
# ADJ: {'TP': 26, 'FP': 3, 'TN': 347, 'FN': 2}
# VERB: {'TP': 46, 'FP': 3, 'TN': 328, 'FN': 1}
# ADP: {'TP': 51, 'FP': 3, 'TN': 324, 'FN': 0}
# .: {'TP': 18, 'FP': 0, 'TN': 344, 'FN': 16}
# ADV: {'TP': 8, 'FP': 0, 'TN': 370, 'FN': 0}
# CONJ: {'TP': 9, 'FP': 1, 'TN': 368, 'FN': 0}
# PRT: {'TP': 12, 'FP': 0, 'TN': 366, 'FN': 0}
# PRON: {'TP': 5, 'FP': 2, 'TN': 371, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 369, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 378, 'FN': 0}
#
# Tag with the most false positives is: DET with 8 counts.
# Tag with the most false negative is:  . with 16 counts.
# sentence:       ['The', 'episode', 'tended', 'to', 'confirm', 'the', 'U.', 'S.', 'belief', 'that', 'propaganda', ',', 'the', 'hope', 'of', 'one-sided', 'concessions', ',', 'and', 'the', 'chance', 'to', 'split', 'the', 'Allies', ',', 'rather', 'than', 'genuine', 'negotiation', ',', 'were', 'the', 'Soviet', "leader's", 'real', 'aims', 'in', 'summitry', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'ADP', 'ADP', 'ADJ', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', '.', 'ADV', 'ADP', 'ADJ', 'NOUN', '.', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'DET']
# DET: {'TP': 61, 'FP': 10, 'TN': 347, 'FN': 0}
# NOUN: {'TP': 128, 'FP': 5, 'TN': 279, 'FN': 6}
# ADJ: {'TP': 28, 'FP': 3, 'TN': 384, 'FN': 3}
# VERB: {'TP': 50, 'FP': 3, 'TN': 364, 'FN': 1}
# ADP: {'TP': 55, 'FP': 3, 'TN': 359, 'FN': 1}
# .: {'TP': 22, 'FP': 0, 'TN': 379, 'FN': 17}
# ADV: {'TP': 8, 'FP': 1, 'TN': 409, 'FN': 0}
# CONJ: {'TP': 10, 'FP': 1, 'TN': 407, 'FN': 0}
# PRT: {'TP': 14, 'FP': 0, 'TN': 404, 'FN': 0}
# PRON: {'TP': 5, 'FP': 2, 'TN': 411, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 409, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 418, 'FN': 0}
#
# Tag with the most false positives is: DET with 10 counts.
# Tag with the most false negative is:  . with 17 counts.
# sentence:       ['Pre-inaugural', 'position', 'Thus', 'when', 'Premier', 'Khrushchev', 'intimated', 'even', 'before', 'inauguration', 'that', 'he', 'hoped', 'for', 'an', 'early', 'meeting', 'with', 'the', 'new', 'President', ',', 'Mr.', 'Kennedy', 'was', 'confronted', 'with', 'a', 'delicate', 'problem', '.']
# hidden s:       ['ADJ', 'NOUN', 'ADV', 'ADV', 'NOUN', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', '.']
# predictions:    ['NOUN', 'NOUN', '.', 'ADV', 'NOUN', 'NOUN', '.', 'ADV', 'ADP', 'NOUN', 'ADP', 'PRON', 'VERB', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN']
# DET: {'TP': 64, 'FP': 10, 'TN': 375, 'FN': 0}
# NOUN: {'TP': 137, 'FP': 8, 'TN': 298, 'FN': 6}
# ADJ: {'TP': 30, 'FP': 3, 'TN': 411, 'FN': 5}
# VERB: {'TP': 53, 'FP': 3, 'TN': 391, 'FN': 2}
# ADP: {'TP': 60, 'FP': 3, 'TN': 385, 'FN': 1}
# .: {'TP': 23, 'FP': 2, 'TN': 406, 'FN': 18}
# ADV: {'TP': 10, 'FP': 1, 'TN': 437, 'FN': 1}
# CONJ: {'TP': 10, 'FP': 1, 'TN': 438, 'FN': 0}
# PRT: {'TP': 14, 'FP': 0, 'TN': 435, 'FN': 0}
# PRON: {'TP': 6, 'FP': 2, 'TN': 441, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 440, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 449, 'FN': 0}
#
# Tag with the most false positives is: DET with 10 counts.
# Tag with the most false negative is:  . with 18 counts.
# sentence:       ['Shortly', 'before', 'his', 'nomination', 'he', 'had', 'set', 'forth', 'his', 'basic', 'view', 'about', 'the', 'problem', 'of', 'negotiations', 'with', 'the', 'Soviet', 'leader', 'in', 'these', 'words', ':', '``', 'As', 'long', 'as', 'Mr.', 'Khrushchev', 'is', 'convinced', 'that', 'the', 'balance', 'of', 'world', 'power', 'is', 'shifting', 'his', 'way', ',', 'no', 'amount', 'of', 'either', 'smiles', 'or', 'toughness', ',', 'neither', 'Camp', 'David', 'talks', 'nor', 'kitchen', 'debates', ',', 'can', 'compel', 'him', 'to', 'enter', 'fruitful', 'negotiations', "''", '.']
# hidden s:       ['ADV', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'ADV', 'ADV', 'ADP', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'CONJ', 'NOUN', 'CONJ', 'NOUN', '.', 'CONJ', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.', 'VERB', 'VERB', 'PRON', 'PRT', 'VERB', 'ADJ', 'NOUN', '.', '.']
# predictions:    ['ADV', 'ADP', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADV', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'ADJ', 'ADP', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'NOUN', 'NOUN', '.', 'VERB', 'VERB', 'PRON', 'PRT', 'VERB', 'ADJ', 'NOUN', '.', 'ADV']
# DET: {'TP': 72, 'FP': 12, 'TN': 433, 'FN': 0}
# NOUN: {'TP': 159, 'FP': 8, 'TN': 344, 'FN': 6}
# ADJ: {'TP': 32, 'FP': 4, 'TN': 476, 'FN': 5}
# VERB: {'TP': 61, 'FP': 3, 'TN': 450, 'FN': 3}
# ADP: {'TP': 69, 'FP': 5, 'TN': 442, 'FN': 1}
# .: {'TP': 29, 'FP': 2, 'TN': 467, 'FN': 19}
# ADV: {'TP': 12, 'FP': 2, 'TN': 500, 'FN': 3}
# CONJ: {'TP': 12, 'FP': 1, 'TN': 502, 'FN': 2}
# PRT: {'TP': 15, 'FP': 0, 'TN': 502, 'FN': 0}
# PRON: {'TP': 8, 'FP': 2, 'TN': 507, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 508, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 517, 'FN': 0}
#
# Tag with the most false positives is: DET with 12 counts.
# Tag with the most false negative is:  . with 19 counts.
# sentence:       ['The', 'President', 'had', 'set', 'for', 'himself', 'the', 'task', ',', 'which', 'he', 'believed', 'vital', ',', 'of', 'awakening', 'the', 'U.', 'S.', 'and', 'its', 'allies', 'to', 'the', 'hard', 'and', 'complex', 'effort', 'necessary', 'to', 'shift', 'that', 'balance', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'PRON', 'DET', 'NOUN', '.', 'DET', 'PRON', 'VERB', 'ADJ', '.', 'ADP', 'VERB', 'DET', 'NOUN', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'CONJ', 'NOUN', 'NOUN', 'ADJ', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'VERB', 'ADP', 'PRON', 'DET', 'NOUN', '.', 'DET', 'PRON', 'VERB', 'ADJ', '.', 'ADP', 'ADP', 'DET', 'NOUN', 'NOUN', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'ADJ', 'PRT', 'VERB', 'ADP', 'NOUN', 'DET']
# DET: {'TP': 78, 'FP': 13, 'TN': 459, 'FN': 1}
# NOUN: {'TP': 166, 'FP': 8, 'TN': 370, 'FN': 7}
# ADJ: {'TP': 35, 'FP': 5, 'TN': 506, 'FN': 5}
# VERB: {'TP': 65, 'FP': 3, 'TN': 479, 'FN': 4}
# ADP: {'TP': 72, 'FP': 7, 'TN': 471, 'FN': 1}
# .: {'TP': 31, 'FP': 2, 'TN': 498, 'FN': 20}
# ADV: {'TP': 12, 'FP': 2, 'TN': 534, 'FN': 3}
# CONJ: {'TP': 14, 'FP': 1, 'TN': 534, 'FN': 2}
# PRT: {'TP': 16, 'FP': 0, 'TN': 535, 'FN': 0}
# PRON: {'TP': 10, 'FP': 2, 'TN': 539, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 542, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 551, 'FN': 0}
#
# Tag with the most false positives is: DET with 13 counts.
# Tag with the most false negative is:  . with 20 counts.
# sentence:       ['He', 'did', 'not', 'want', 'the', 'effort', 'weakened', 'by', 'any', 'illusion', 'that', 'summit', 'magic', 'might', 'make', 'it', 'unnecessary', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'VERB', 'VERB', 'PRON', 'ADJ', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'PRON', 'ADJ', 'PRON']
# DET: {'TP': 80, 'FP': 14, 'TN': 474, 'FN': 1}
# NOUN: {'TP': 168, 'FP': 10, 'TN': 382, 'FN': 9}
# ADJ: {'TP': 36, 'FP': 6, 'TN': 522, 'FN': 5}
# VERB: {'TP': 68, 'FP': 3, 'TN': 492, 'FN': 6}
# ADP: {'TP': 74, 'FP': 7, 'TN': 487, 'FN': 1}
# .: {'TP': 31, 'FP': 2, 'TN': 515, 'FN': 21}
# ADV: {'TP': 13, 'FP': 2, 'TN': 551, 'FN': 3}
# CONJ: {'TP': 14, 'FP': 1, 'TN': 552, 'FN': 2}
# PRT: {'TP': 16, 'FP': 0, 'TN': 553, 'FN': 0}
# PRON: {'TP': 12, 'FP': 3, 'TN': 554, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 560, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 569, 'FN': 0}
#
# Tag with the most false positives is: DET with 14 counts.
# Tag with the most false negative is:  . with 21 counts.
# sentence:       ['He', 'wanted', 'time', ',', 'too', ',', 'to', 'review', 'the', 'United', "States'", 'global', 'commitments', 'and', 'to', 'test', 'both', 'the', 'policies', 'he', 'had', 'inherited', 'and', 'new', 'ones', 'he', 'was', 'formulating', '.']
# hidden s:       ['PRON', 'VERB', 'NOUN', '.', 'ADV', '.', 'PRT', 'VERB', 'DET', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'CONJ', 'PRT', 'VERB', 'DET', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'CONJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'VERB', '.']
# predictions:    ['PRON', 'VERB', 'NOUN', '.', 'ADV', '.', 'ADP', 'NOUN', 'DET', 'VERB', 'NOUN', 'ADJ', 'NOUN', 'CONJ', 'PRT', 'VERB', 'DET', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'CONJ', 'ADJ', 'NOUN', 'PRON', 'VERB', 'NOUN', 'PRON']
# DET: {'TP': 83, 'FP': 14, 'TN': 500, 'FN': 1}
# NOUN: {'TP': 173, 'FP': 12, 'TN': 404, 'FN': 9}
# ADJ: {'TP': 38, 'FP': 6, 'TN': 549, 'FN': 5}
# VERB: {'TP': 74, 'FP': 3, 'TN': 513, 'FN': 8}
# ADP: {'TP': 74, 'FP': 8, 'TN': 515, 'FN': 1}
# .: {'TP': 33, 'FP': 2, 'TN': 541, 'FN': 22}
# ADV: {'TP': 14, 'FP': 2, 'TN': 579, 'FN': 3}
# CONJ: {'TP': 16, 'FP': 1, 'TN': 579, 'FN': 2}
# PRT: {'TP': 17, 'FP': 0, 'TN': 580, 'FN': 1}
# PRON: {'TP': 15, 'FP': 4, 'TN': 579, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 589, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 598, 'FN': 0}
#
# Tag with the most false positives is: DET with 14 counts.
# Tag with the most false negative is:  . with 22 counts.
# sentence:       ['Above', 'all', ',', 'he', 'did', 'not', 'want', 'to', 'appear', 'to', 'be', 'running', 'hat', 'in', 'hand', 'to', 'Premier', "Khrushchev's", 'doorstep', '.']
# hidden s:       ['ADP', 'PRT', '.', 'PRON', 'VERB', 'ADV', 'VERB', 'PRT', 'VERB', 'PRT', 'VERB', 'VERB', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', '.']
# predictions:    ['VERB', 'PRT', '.', 'PRON', 'VERB', 'ADV', 'VERB', 'PRT', 'VERB', 'PRT', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'NOUN', 'VERB']
# DET: {'TP': 83, 'FP': 14, 'TN': 520, 'FN': 1}
# NOUN: {'TP': 177, 'FP': 12, 'TN': 419, 'FN': 10}
# ADJ: {'TP': 38, 'FP': 6, 'TN': 569, 'FN': 5}
# VERB: {'TP': 79, 'FP': 6, 'TN': 525, 'FN': 8}
# ADP: {'TP': 76, 'FP': 8, 'TN': 532, 'FN': 2}
# .: {'TP': 34, 'FP': 2, 'TN': 559, 'FN': 23}
# ADV: {'TP': 15, 'FP': 2, 'TN': 598, 'FN': 3}
# CONJ: {'TP': 16, 'FP': 1, 'TN': 599, 'FN': 2}
# PRT: {'TP': 20, 'FP': 0, 'TN': 597, 'FN': 1}
# PRON: {'TP': 16, 'FP': 4, 'TN': 598, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 609, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 618, 'FN': 0}
#
# Tag with the most false positives is: DET with 14 counts.
# Tag with the most false negative is:  . with 23 counts.
# sentence:       ['Attitude', 'flexible', 'At', 'the', 'same', 'time', 'the', 'President', 'took', 'pains', 'not', 'to', 'rule', 'out', 'an', 'eventual', 'meeting', 'with', 'the', 'Soviet', 'leader', '.']
# hidden s:       ['NOUN', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'VERB', 'NOUN', 'ADV', 'PRT', 'VERB', 'PRT', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'ADJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'DET', 'NOUN', 'VERB', 'NOUN', 'ADV', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'DET']
# DET: {'TP': 87, 'FP': 16, 'TN': 536, 'FN': 1}
# NOUN: {'TP': 183, 'FP': 14, 'TN': 432, 'FN': 11}
# ADJ: {'TP': 40, 'FP': 6, 'TN': 588, 'FN': 6}
# VERB: {'TP': 80, 'FP': 6, 'TN': 545, 'FN': 9}
# ADP: {'TP': 78, 'FP': 10, 'TN': 550, 'FN': 2}
# .: {'TP': 34, 'FP': 2, 'TN': 580, 'FN': 24}
# ADV: {'TP': 16, 'FP': 2, 'TN': 619, 'FN': 3}
# CONJ: {'TP': 16, 'FP': 1, 'TN': 621, 'FN': 2}
# PRT: {'TP': 20, 'FP': 0, 'TN': 617, 'FN': 3}
# PRON: {'TP': 16, 'FP': 4, 'TN': 620, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 631, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 640, 'FN': 0}
#
# Tag with the most false positives is: DET with 16 counts.
# Tag with the most false negative is:  . with 24 counts.
# sentence:       ['Ideally', ',', 'he', 'knew', ',', 'it', 'should', 'be', 'preceded', 'by', 'concrete', 'progress', 'at', 'lower', 'levels', '.']
# hidden s:       ['ADV', '.', 'PRON', 'VERB', '.', 'PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['NOUN', '.', 'PRON', 'VERB', '.', 'PRON', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN']
# DET: {'TP': 87, 'FP': 17, 'TN': 551, 'FN': 1}
# NOUN: {'TP': 185, 'FP': 16, 'TN': 444, 'FN': 11}
# ADJ: {'TP': 41, 'FP': 6, 'TN': 602, 'FN': 7}
# VERB: {'TP': 84, 'FP': 6, 'TN': 557, 'FN': 9}
# ADP: {'TP': 80, 'FP': 10, 'TN': 564, 'FN': 2}
# .: {'TP': 36, 'FP': 2, 'TN': 593, 'FN': 25}
# ADV: {'TP': 16, 'FP': 2, 'TN': 634, 'FN': 4}
# CONJ: {'TP': 16, 'FP': 1, 'TN': 637, 'FN': 2}
# PRT: {'TP': 20, 'FP': 0, 'TN': 633, 'FN': 3}
# PRON: {'TP': 18, 'FP': 4, 'TN': 634, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 647, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 656, 'FN': 0}
#
# Tag with the most false positives is: DET with 17 counts.
# Tag with the most false negative is:  . with 25 counts.
# sentence:       ['But', 'Mr.', 'Kennedy', 'saw', 'value', 'even', 'in', 'an', 'informal', 'meeting', ',', 'provided', 'that', 'undue', 'hopes', 'were', 'not', 'raised', 'in', 'connection', 'with', 'it', '.']
# hidden s:       ['CONJ', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'VERB', 'ADP', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADP', 'NOUN', 'ADP', 'PRON', '.']
# predictions:    ['CONJ', 'NOUN', 'NOUN', 'VERB', 'NOUN', 'ADV', 'ADP', 'DET', 'NOUN', 'NOUN', '.', 'VERB', 'ADP', 'ADJ', 'VERB', 'VERB', 'ADV', 'VERB', 'ADP', 'NOUN', 'ADP', 'PRON', 'CONJ']
# DET: {'TP': 88, 'FP': 17, 'TN': 573, 'FN': 1}
# NOUN: {'TP': 190, 'FP': 17, 'TN': 460, 'FN': 12}
# ADJ: {'TP': 42, 'FP': 6, 'TN': 623, 'FN': 8}
# VERB: {'TP': 88, 'FP': 7, 'TN': 575, 'FN': 9}
# ADP: {'TP': 84, 'FP': 10, 'TN': 583, 'FN': 2}
# .: {'TP': 37, 'FP': 2, 'TN': 614, 'FN': 26}
# ADV: {'TP': 18, 'FP': 2, 'TN': 655, 'FN': 4}
# CONJ: {'TP': 17, 'FP': 2, 'TN': 658, 'FN': 2}
# PRT: {'TP': 20, 'FP': 0, 'TN': 656, 'FN': 3}
# PRON: {'TP': 19, 'FP': 4, 'TN': 656, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 670, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 679, 'FN': 0}
#
# Tag with the most false positives is: DET with 17 counts.
# Tag with the most false negative is:  . with 26 counts.
# sentence:       ['It', 'would', 'give', 'him', 'an', 'opportunity', 'to', 'take', 'the', 'measure', 'of', 'his', 'chief', 'adversary', 'in', 'the', 'cold', 'war', ',', 'to', 'try', 'to', 'probe', 'Mr.', "Khrushchev's", 'intentions', 'and', 'to', 'make', 'clear', 'his', 'own', 'views', '.']
# hidden s:       ['PRON', 'VERB', 'VERB', 'PRON', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'PRT', 'VERB', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'PRT', 'VERB', 'ADJ', 'DET', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'VERB', 'PRON', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'PRT', 'VERB', 'ADP', 'DET', 'NOUN', 'NOUN', 'NOUN', 'CONJ', 'PRT', 'VERB', 'VERB', 'DET', 'ADJ', 'NOUN', 'PRON']
# DET: {'TP': 93, 'FP': 18, 'TN': 601, 'FN': 1}
# NOUN: {'TP': 198, 'FP': 17, 'TN': 486, 'FN': 12}
# ADJ: {'TP': 45, 'FP': 6, 'TN': 653, 'FN': 9}
# VERB: {'TP': 93, 'FP': 8, 'TN': 602, 'FN': 10}
# ADP: {'TP': 86, 'FP': 11, 'TN': 614, 'FN': 2}
# .: {'TP': 38, 'FP': 2, 'TN': 646, 'FN': 27}
# ADV: {'TP': 18, 'FP': 2, 'TN': 689, 'FN': 4}
# CONJ: {'TP': 18, 'FP': 2, 'TN': 691, 'FN': 2}
# PRT: {'TP': 23, 'FP': 0, 'TN': 686, 'FN': 4}
# PRON: {'TP': 21, 'FP': 5, 'TN': 687, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 704, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 713, 'FN': 0}
#
# Tag with the most false positives is: DET with 18 counts.
# Tag with the most false negative is:  . with 27 counts.
# sentence:       ['Moreover', ',', 'an', 'eventual', 'meeting', 'was', 'desirable', 'if', 'for', 'no', 'other', 'reason', 'than', 'to', 'satisfy', 'world', 'opinion', 'that', 'the', 'U.', 'S.', 'was', 'not', 'inflexible', 'and', 'was', 'sparing', 'no', 'effort', 'to', 'ease', 'international', 'tensions', '.']
# hidden s:       ['ADV', '.', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADJ', 'ADP', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'PRT', 'VERB', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'CONJ', 'VERB', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', '.']
# predictions:    ['ADV', '.', 'DET', 'NOUN', 'NOUN', 'VERB', 'ADJ', 'ADP', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'ADV', '.', 'CONJ', 'VERB', 'ADP', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADV']
# DET: {'TP': 97, 'FP': 19, 'TN': 630, 'FN': 1}
# NOUN: {'TP': 206, 'FP': 18, 'TN': 511, 'FN': 12}
# ADJ: {'TP': 48, 'FP': 6, 'TN': 682, 'FN': 11}
# VERB: {'TP': 97, 'FP': 8, 'TN': 630, 'FN': 12}
# ADP: {'TP': 90, 'FP': 13, 'TN': 642, 'FN': 2}
# .: {'TP': 39, 'FP': 3, 'TN': 677, 'FN': 28}
# ADV: {'TP': 20, 'FP': 3, 'TN': 720, 'FN': 4}
# CONJ: {'TP': 19, 'FP': 2, 'TN': 724, 'FN': 2}
# PRT: {'TP': 24, 'FP': 0, 'TN': 718, 'FN': 5}
# PRON: {'TP': 21, 'FP': 5, 'TN': 721, 'FN': 0}
# NUM: {'TP': 9, 'FP': 0, 'TN': 738, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 747, 'FN': 0}
#
# Tag with the most false positives is: DET with 19 counts.
# Tag with the most false negative is:  . with 28 counts.
# sentence:       ['Both', 'elements', '--', 'the', 'caution', 'about', 'a', 'meeting', ',', 'the', 'willingness', 'eventually', 'to', 'hold', 'one', '--', 'were', 'reflected', 'in', 'a', 'letter', 'from', 'the', 'President', 'which', 'Ambassador', 'Llewellyn', 'E.', 'Thompson', 'brought', 'back', 'to', 'Russia', 'late', 'in', 'February', '.']
# hidden s:       ['DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADV', 'PRT', 'VERB', 'NUM', '.', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', 'ADV', 'PRT', 'VERB', 'NUM', '.', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'DET', 'NOUN', 'NOUN', 'NOUN', 'NOUN', 'VERB', 'ADV', 'ADP', 'NOUN', 'ADV', 'ADP', 'NOUN', 'DET']
# DET: {'TP': 104, 'FP': 20, 'TN': 659, 'FN': 1}
# NOUN: {'TP': 218, 'FP': 18, 'TN': 536, 'FN': 12}
# ADJ: {'TP': 48, 'FP': 6, 'TN': 719, 'FN': 11}
# VERB: {'TP': 101, 'FP': 8, 'TN': 663, 'FN': 12}
# ADP: {'TP': 95, 'FP': 13, 'TN': 674, 'FN': 2}
# .: {'TP': 42, 'FP': 3, 'TN': 710, 'FN': 29}
# ADV: {'TP': 23, 'FP': 3, 'TN': 754, 'FN': 4}
# CONJ: {'TP': 19, 'FP': 2, 'TN': 761, 'FN': 2}
# PRT: {'TP': 25, 'FP': 0, 'TN': 754, 'FN': 5}
# PRON: {'TP': 21, 'FP': 5, 'TN': 758, 'FN': 0}
# NUM: {'TP': 10, 'FP': 0, 'TN': 774, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 784, 'FN': 0}
#
# Tag with the most false positives is: DET with 20 counts.
# Tag with the most false negative is:  . with 29 counts.
# sentence:       ['The', 'letter', ',', 'dated', 'Feb.', '22', ',', 'was', 'delivered', 'to', 'Premier', 'Khrushchev', 'in', 'Novosibirsk', ',', 'Siberia', ',', 'on', 'March', '9', '.']
# hidden s:       ['DET', 'NOUN', '.', 'VERB', 'NOUN', 'NUM', '.', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'ADP', 'NOUN', 'NUM', '.']
# predictions:    ['DET', 'NOUN', '.', 'DET', 'NOUN', 'NUM', '.', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.', 'NOUN', '.', 'ADP', 'NOUN', 'NUM', 'DET']
# DET: {'TP': 105, 'FP': 22, 'TN': 677, 'FN': 1}
# NOUN: {'TP': 225, 'FP': 18, 'TN': 550, 'FN': 12}
# ADJ: {'TP': 48, 'FP': 6, 'TN': 740, 'FN': 11}
# VERB: {'TP': 103, 'FP': 8, 'TN': 681, 'FN': 13}
# ADP: {'TP': 98, 'FP': 13, 'TN': 692, 'FN': 2}
# .: {'TP': 46, 'FP': 3, 'TN': 726, 'FN': 30}
# ADV: {'TP': 23, 'FP': 3, 'TN': 775, 'FN': 4}
# CONJ: {'TP': 19, 'FP': 2, 'TN': 782, 'FN': 2}
# PRT: {'TP': 25, 'FP': 0, 'TN': 775, 'FN': 5}
# PRON: {'TP': 21, 'FP': 5, 'TN': 779, 'FN': 0}
# NUM: {'TP': 12, 'FP': 0, 'TN': 793, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 805, 'FN': 0}
#
# Tag with the most false positives is: DET with 22 counts.
# Tag with the most false negative is:  . with 30 counts.
# sentence:       ['It', 'dealt', 'mainly', 'with', 'a', 'broad', 'range', 'of', 'East-West', 'issues', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'PRON']
# DET: {'TP': 106, 'FP': 22, 'TN': 687, 'FN': 1}
# NOUN: {'TP': 227, 'FP': 19, 'TN': 558, 'FN': 12}
# ADJ: {'TP': 49, 'FP': 6, 'TN': 749, 'FN': 12}
# VERB: {'TP': 104, 'FP': 8, 'TN': 691, 'FN': 13}
# ADP: {'TP': 100, 'FP': 13, 'TN': 701, 'FN': 2}
# .: {'TP': 46, 'FP': 3, 'TN': 736, 'FN': 31}
# ADV: {'TP': 24, 'FP': 3, 'TN': 785, 'FN': 4}
# CONJ: {'TP': 19, 'FP': 2, 'TN': 793, 'FN': 2}
# PRT: {'TP': 25, 'FP': 0, 'TN': 786, 'FN': 5}
# PRON: {'TP': 22, 'FP': 6, 'TN': 788, 'FN': 0}
# NUM: {'TP': 12, 'FP': 0, 'TN': 804, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 816, 'FN': 0}
#
# Tag with the most false positives is: DET with 22 counts.
# Tag with the most false negative is:  . with 31 counts.
# sentence:       ['But', 'it', 'also', 'briefly', 'suggested', 'the', 'possibility', 'of', 'a', 'meeting', 'with', 'Mr.', 'Khrushchev', 'before', 'the', 'end', 'of', 'the', 'year', 'if', 'the', 'international', 'climate', 'were', 'favorable', 'and', 'schedules', 'permitted', '.']
# hidden s:       ['CONJ', 'PRON', 'ADV', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADJ', 'CONJ', 'NOUN', 'VERB', '.']
# predictions:    ['CONJ', 'PRON', 'ADV', 'VERB', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'ADJ', 'CONJ', 'NOUN', 'VERB', 'CONJ']
# DET: {'TP': 111, 'FP': 22, 'TN': 711, 'FN': 1}
# NOUN: {'TP': 235, 'FP': 19, 'TN': 579, 'FN': 12}
# ADJ: {'TP': 51, 'FP': 6, 'TN': 776, 'FN': 12}
# VERB: {'TP': 107, 'FP': 9, 'TN': 716, 'FN': 13}
# ADP: {'TP': 105, 'FP': 13, 'TN': 725, 'FN': 2}
# .: {'TP': 46, 'FP': 3, 'TN': 764, 'FN': 32}
# ADV: {'TP': 25, 'FP': 3, 'TN': 812, 'FN': 5}
# CONJ: {'TP': 21, 'FP': 3, 'TN': 819, 'FN': 2}
# PRT: {'TP': 25, 'FP': 0, 'TN': 815, 'FN': 5}
# PRON: {'TP': 23, 'FP': 6, 'TN': 816, 'FN': 0}
# NUM: {'TP': 12, 'FP': 0, 'TN': 833, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 845, 'FN': 0}
#
# Tag with the most false positives is: DET with 22 counts.
# Tag with the most false negative is:  . with 32 counts.
# sentence:       ['Developments', 'over', 'the', 'next', 'two', 'months', ',', 'however', ',', 'caused', 'the', 'President', 'to', 'reconsider', 'the', 'question', 'of', 'the', 'timing', '.']
# hidden s:       ['NOUN', 'ADP', 'DET', 'ADJ', 'NUM', 'NOUN', '.', 'ADV', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['NOUN', 'ADP', 'DET', 'ADJ', 'NUM', 'NOUN', '.', 'ADV', '.', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN']
# DET: {'TP': 115, 'FP': 22, 'TN': 727, 'FN': 1}
# NOUN: {'TP': 240, 'FP': 20, 'TN': 593, 'FN': 12}
# ADJ: {'TP': 52, 'FP': 6, 'TN': 795, 'FN': 12}
# VERB: {'TP': 109, 'FP': 9, 'TN': 734, 'FN': 13}
# ADP: {'TP': 107, 'FP': 13, 'TN': 743, 'FN': 2}
# .: {'TP': 48, 'FP': 3, 'TN': 781, 'FN': 33}
# ADV: {'TP': 26, 'FP': 3, 'TN': 831, 'FN': 5}
# CONJ: {'TP': 21, 'FP': 3, 'TN': 839, 'FN': 2}
# PRT: {'TP': 26, 'FP': 0, 'TN': 834, 'FN': 5}
# PRON: {'TP': 23, 'FP': 6, 'TN': 836, 'FN': 0}
# NUM: {'TP': 13, 'FP': 0, 'TN': 852, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 865, 'FN': 0}
#
# Tag with the most false positives is: DET with 22 counts.
# Tag with the most false negative is:  . with 33 counts.
# sentence:       ['There', 'were', 'intense', 'discussions', 'in', 'the', 'inner', 'councils', 'of', 'the', 'White', 'House', 'about', 'the', 'advisability', 'of', 'an', 'early', 'meeting', ',', 'not', 'because', 'the', 'international', 'climate', 'was', 'improving', ',', 'but', 'precisely', 'because', 'it', 'was', 'deteriorating', 'alarmingly', '.']
# hidden s:       ['PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'ADV', 'ADP', 'PRON', 'VERB', 'VERB', 'ADV', '.']
# predictions:    ['PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'ADP', 'DET', 'ADJ', 'NOUN', 'VERB', 'VERB', '.', 'CONJ', 'NOUN', 'ADP', 'PRON', 'VERB', 'DET', 'NOUN', 'PRT']
# DET: {'TP': 120, 'FP': 24, 'TN': 756, 'FN': 1}
# NOUN: {'TP': 246, 'FP': 23, 'TN': 620, 'FN': 12}
# ADJ: {'TP': 55, 'FP': 6, 'TN': 826, 'FN': 14}
# VERB: {'TP': 113, 'FP': 9, 'TN': 765, 'FN': 14}
# ADP: {'TP': 113, 'FP': 13, 'TN': 773, 'FN': 2}
# .: {'TP': 50, 'FP': 3, 'TN': 814, 'FN': 34}
# ADV: {'TP': 27, 'FP': 3, 'TN': 864, 'FN': 7}
# CONJ: {'TP': 22, 'FP': 3, 'TN': 874, 'FN': 2}
# PRT: {'TP': 27, 'FP': 1, 'TN': 868, 'FN': 5}
# PRON: {'TP': 24, 'FP': 6, 'TN': 871, 'FN': 0}
# NUM: {'TP': 13, 'FP': 0, 'TN': 888, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 901, 'FN': 0}
#
# Tag with the most false positives is: DET with 24 counts.
# Tag with the most false negative is:  . with 34 counts.
# sentence:       ['Deadlock', 'on', 'tests', 'The', 'President', 'was', 'especially', 'concerned', 'about', 'the', 'deadlock', 'in', 'the', 'nuclear', 'test', 'ban', 'negotiations', 'at', 'Geneva', '.']
# hidden s:       ['NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'NOUN']
# DET: {'TP': 123, 'FP': 24, 'TN': 773, 'FN': 1}
# NOUN: {'TP': 254, 'FP': 24, 'TN': 631, 'FN': 12}
# ADJ: {'TP': 56, 'FP': 6, 'TN': 845, 'FN': 14}
# VERB: {'TP': 115, 'FP': 9, 'TN': 783, 'FN': 14}
# ADP: {'TP': 117, 'FP': 13, 'TN': 789, 'FN': 2}
# .: {'TP': 50, 'FP': 3, 'TN': 833, 'FN': 35}
# ADV: {'TP': 28, 'FP': 3, 'TN': 883, 'FN': 7}
# CONJ: {'TP': 22, 'FP': 3, 'TN': 894, 'FN': 2}
# PRT: {'TP': 27, 'FP': 1, 'TN': 888, 'FN': 5}
# PRON: {'TP': 24, 'FP': 6, 'TN': 891, 'FN': 0}
# NUM: {'TP': 13, 'FP': 0, 'TN': 908, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 921, 'FN': 0}
#
# Tag with the most false positives is: DET with 24 counts.
# Tag with the most false negative is:  . with 35 counts.
# sentence:       ['The', 'deadlock', 'has', 'been', 'caused', 'by', 'the', "Russians'", 'new', 'demand', 'for', 'a', 'three-man', '(', 'East', ',', 'West', 'and', 'neutral', ')', 'directorate', ',', 'and', 'thus', 'a', 'veto', ',', 'over', 'the', 'control', 'machinery', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'NOUN', 'ADJ', 'NOUN', 'ADP', 'DET', 'ADJ', '.', 'NOUN', '.', 'ADJ', 'CONJ', 'ADJ', '.', 'NOUN', '.', 'CONJ', 'ADV', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'DET', 'ADJ', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', '.', 'NOUN', '.', 'ADJ', 'CONJ', 'ADJ', '.', 'NOUN', '.', 'CONJ', 'ADV', 'DET', 'NOUN', '.', 'ADP', 'DET', 'NOUN', 'NOUN', 'DET']
# DET: {'TP': 128, 'FP': 25, 'TN': 799, 'FN': 1}
# NOUN: {'TP': 261, 'FP': 25, 'TN': 654, 'FN': 13}
# ADJ: {'TP': 59, 'FP': 7, 'TN': 872, 'FN': 15}
# VERB: {'TP': 118, 'FP': 9, 'TN': 812, 'FN': 14}
# ADP: {'TP': 120, 'FP': 13, 'TN': 818, 'FN': 2}
# .: {'TP': 55, 'FP': 3, 'TN': 859, 'FN': 36}
# ADV: {'TP': 29, 'FP': 3, 'TN': 914, 'FN': 7}
# CONJ: {'TP': 24, 'FP': 3, 'TN': 924, 'FN': 2}
# PRT: {'TP': 27, 'FP': 1, 'TN': 920, 'FN': 5}
# PRON: {'TP': 24, 'FP': 6, 'TN': 923, 'FN': 0}
# NUM: {'TP': 13, 'FP': 0, 'TN': 940, 'FN': 0}
# X: {'TP': 0, 'FP': 0, 'TN': 953, 'FN': 0}
#
# Tag with the most false positives is: DET with 25 counts.
# Tag with the most false negative is:  . with 36 counts.
# sentence:       ['In', 'the', 'U.', 'S.', ',', 'strong', 'pressures', 'have', 'been', 'building', 'up', 'for', 'a', 'resumption', 'of', 'tests', 'on', 'grounds', 'that', 'the', 'Russians', 'may', 'be', 'secretly', 'testing', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'NOUN', '.', 'ADJ', 'NOUN', 'VERB', 'VERB', 'VERB', 'PRT', 'ADP', 'DET', 'NOUN', 'ADP', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'VERB', 'ADV', 'VERB', '.']
# ...
# ADJ: {'TP': 1399, 'FP': 172, 'TN': 22698, 'FN': 583}
# VERB: {'TP': 3109, 'FP': 259, 'TN': 21027, 'FN': 457}
# ADP: {'TP': 3031, 'FP': 459, 'TN': 21250, 'FN': 112}
# .: {'TP': 2172, 'FP': 59, 'TN': 21733, 'FN': 888}
# ADV: {'TP': 847, 'FP': 144, 'TN': 23639, 'FN': 222}
# CONJ: {'TP': 716, 'FP': 58, 'TN': 24071, 'FN': 7}
# PRT: {'TP': 561, 'FP': 87, 'TN': 24111, 'FN': 93}
# PRON: {'TP': 636, 'FP': 123, 'TN': 24082, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24356, 'FN': 83}
# X: {'TP': 13, 'FP': 1, 'TN': 24810, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1022 counts.
# Tag with the most false negative is:  . with 888 counts.
# sentence:       ['We', 'must', 'not', 'permit', 'our', 'society', 'to', 'become', 'a', 'slave', 'to', 'the', 'scientific', 'age', ',', 'as', 'might', 'well', 'happen', 'without', 'the', 'cultural', 'and', 'spiritual', 'restraint', 'that', 'comes', 'from', 'the', 'development', 'of', 'the', 'human', 'mind', 'through', 'wisdom', 'absorbed', 'from', 'the', 'written', 'word', '.']
# hidden s:       ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADP', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'ADJ', 'NOUN', 'DET', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['PRON', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'PRT', 'VERB', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', '.', 'ADV', 'VERB', 'ADV', 'VERB', 'ADP', 'DET', 'ADJ', 'CONJ', 'NOUN', '.', 'PRON', 'VERB', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', 'PRON']
# DET: {'TP': 2937, 'FP': 542, 'TN': 21380, 'FN': 35}
# NOUN: {'TP': 6107, 'FP': 1023, 'TN': 17341, 'FN': 423}
# ADJ: {'TP': 1401, 'FP': 172, 'TN': 22737, 'FN': 584}
# VERB: {'TP': 3117, 'FP': 259, 'TN': 21061, 'FN': 457}
# ADP: {'TP': 3037, 'FP': 459, 'TN': 21285, 'FN': 113}
# .: {'TP': 2173, 'FP': 60, 'TN': 21772, 'FN': 889}
# ADV: {'TP': 849, 'FP': 145, 'TN': 23678, 'FN': 222}
# CONJ: {'TP': 717, 'FP': 58, 'TN': 24112, 'FN': 7}
# PRT: {'TP': 562, 'FP': 87, 'TN': 24152, 'FN': 93}
# PRON: {'TP': 637, 'FP': 125, 'TN': 24121, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24398, 'FN': 83}
# X: {'TP': 13, 'FP': 1, 'TN': 24852, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1023 counts.
# Tag with the most false negative is:  . with 889 counts.
# sentence:       ['A', 'fundamental', 'source', 'of', 'knowledge', 'in', 'the', 'world', 'today', 'is', 'the', 'book', 'found', 'in', 'our', 'libraries', '.']
# hidden s:       ['DET', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'DET', 'NOUN', 'VERB', 'ADP', 'DET', 'NOUN', 'DET']
# DET: {'TP': 2941, 'FP': 543, 'TN': 21392, 'FN': 35}
# NOUN: {'TP': 6113, 'FP': 1024, 'TN': 17351, 'FN': 423}
# ADJ: {'TP': 1401, 'FP': 172, 'TN': 22753, 'FN': 585}
# VERB: {'TP': 3119, 'FP': 259, 'TN': 21076, 'FN': 457}
# ADP: {'TP': 3040, 'FP': 459, 'TN': 21299, 'FN': 113}
# .: {'TP': 2173, 'FP': 60, 'TN': 21788, 'FN': 890}
# ADV: {'TP': 849, 'FP': 145, 'TN': 23695, 'FN': 222}
# CONJ: {'TP': 717, 'FP': 58, 'TN': 24129, 'FN': 7}
# PRT: {'TP': 562, 'FP': 87, 'TN': 24169, 'FN': 93}
# PRON: {'TP': 637, 'FP': 125, 'TN': 24138, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24415, 'FN': 83}
# X: {'TP': 13, 'FP': 1, 'TN': 24869, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1024 counts.
# Tag with the most false negative is:  . with 890 counts.
# sentence:       ['Although', 'progress', 'has', 'been', 'made', 'in', "America's", 'system', 'of', 'libraries', 'it', 'still', 'falls', 'short', 'of', 'what', 'is', 'required', 'if', 'we', 'are', 'to', 'maintain', 'the', 'standards', 'that', 'are', 'needed', 'for', 'an', 'informed', 'America', '.']
# hidden s:       ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'VERB', 'VERB', 'VERB', 'ADP', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'PRON', 'ADV', 'VERB', 'ADV', 'ADP', 'DET', 'VERB', 'VERB', 'ADP', 'PRON', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'PRON', 'VERB', 'VERB', 'ADP', 'DET', 'VERB', 'NOUN', 'ADP']
# DET: {'TP': 2944, 'FP': 543, 'TN': 21422, 'FN': 35}
# NOUN: {'TP': 6119, 'FP': 1024, 'TN': 17378, 'FN': 423}
# ADJ: {'TP': 1401, 'FP': 172, 'TN': 22786, 'FN': 585}
# VERB: {'TP': 3130, 'FP': 259, 'TN': 21098, 'FN': 457}
# ADP: {'TP': 3046, 'FP': 460, 'TN': 21325, 'FN': 113}
# .: {'TP': 2173, 'FP': 60, 'TN': 21820, 'FN': 891}
# ADV: {'TP': 851, 'FP': 145, 'TN': 23726, 'FN': 222}
# CONJ: {'TP': 717, 'FP': 58, 'TN': 24162, 'FN': 7}
# PRT: {'TP': 563, 'FP': 87, 'TN': 24201, 'FN': 93}
# PRON: {'TP': 640, 'FP': 125, 'TN': 24168, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24448, 'FN': 83}
# X: {'TP': 13, 'FP': 1, 'TN': 24902, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1024 counts.
# Tag with the most false negative is:  . with 891 counts.
# sentence:       ['The', 'problem', 'grows', 'in', 'intensity', 'each', 'year', 'as', "man's", 'knowledge', ',', 'and', 'his', 'capacity', 'to', 'translate', 'such', 'knowledge', 'to', 'the', 'written', 'word', ',', 'continue', 'to', 'expand', '.']
# hidden s:       ['DET', 'NOUN', 'VERB', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'PRT', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', '.']
# predictions:    ['DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'DET', 'NOUN', 'ADP', 'NOUN', 'NOUN', '.', 'CONJ', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'VERB', 'NOUN', '.', 'VERB', 'PRT', 'VERB', 'DET']
# DET: {'TP': 2948, 'FP': 545, 'TN': 21443, 'FN': 35}
# NOUN: {'TP': 6127, 'FP': 1025, 'TN': 17396, 'FN': 423}
# ADJ: {'TP': 1402, 'FP': 172, 'TN': 22812, 'FN': 585}
# VERB: {'TP': 3133, 'FP': 259, 'TN': 21120, 'FN': 459}
# ADP: {'TP': 3049, 'FP': 461, 'TN': 21348, 'FN': 113}
# .: {'TP': 2175, 'FP': 60, 'TN': 21844, 'FN': 892}
# ADV: {'TP': 851, 'FP': 145, 'TN': 23753, 'FN': 222}
# CONJ: {'TP': 718, 'FP': 58, 'TN': 24188, 'FN': 7}
# PRT: {'TP': 564, 'FP': 87, 'TN': 24226, 'FN': 94}
# PRON: {'TP': 640, 'FP': 125, 'TN': 24195, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24475, 'FN': 83}
# X: {'TP': 13, 'FP': 1, 'TN': 24929, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1025 counts.
# Tag with the most false negative is:  . with 892 counts.
# sentence:       ['The', 'inadequacy', 'of', 'our', 'library', 'system', 'will', 'become', 'critical', 'unless', 'we', 'act', 'vigorously', 'to', 'correct', 'this', 'condition', '.']
# hidden s:       ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'ADV', 'PRT', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['DET', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'VERB', 'VERB', 'ADJ', 'ADP', 'PRON', 'VERB', 'VERB', 'PRT', 'VERB', 'DET', 'NOUN', 'DET']
# DET: {'TP': 2951, 'FP': 546, 'TN': 21457, 'FN': 35}
# NOUN: {'TP': 6131, 'FP': 1025, 'TN': 17410, 'FN': 423}
# ADJ: {'TP': 1403, 'FP': 172, 'TN': 22829, 'FN': 585}
# VERB: {'TP': 3137, 'FP': 260, 'TN': 21133, 'FN': 459}
# ADP: {'TP': 3051, 'FP': 461, 'TN': 21364, 'FN': 113}
# .: {'TP': 2175, 'FP': 60, 'TN': 21861, 'FN': 893}
# ADV: {'TP': 851, 'FP': 145, 'TN': 23770, 'FN': 223}
# CONJ: {'TP': 718, 'FP': 58, 'TN': 24206, 'FN': 7}
# PRT: {'TP': 565, 'FP': 87, 'TN': 24243, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24212, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24493, 'FN': 83}
# X: {'TP': 13, 'FP': 1, 'TN': 24947, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1025 counts.
# Tag with the most false negative is:  . with 893 counts.
# sentence:       ['There', 'are', ',', 'for', 'example', ',', 'approximately', '25,000,000', 'people', 'in', 'this', 'country', 'with', 'no', 'public', 'library', 'service', 'and', 'about', '50,000,000', 'with', 'inadequate', 'service', '.']
# hidden s:       ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'NUM', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'NUM', 'ADP', 'ADJ', 'NOUN', '.']
# predictions:    ['PRT', 'VERB', '.', 'ADP', 'NOUN', '.', 'ADV', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'NOUN', 'CONJ', 'ADV', 'VERB', 'ADP', 'ADJ', 'NOUN', 'PRT']
# DET: {'TP': 2953, 'FP': 546, 'TN': 21479, 'FN': 35}
# NOUN: {'TP': 6137, 'FP': 1025, 'TN': 17428, 'FN': 423}
# ADJ: {'TP': 1405, 'FP': 173, 'TN': 22850, 'FN': 585}
# VERB: {'TP': 3138, 'FP': 261, 'TN': 21155, 'FN': 459}
# ADP: {'TP': 3055, 'FP': 461, 'TN': 21384, 'FN': 113}
# .: {'TP': 2177, 'FP': 60, 'TN': 21882, 'FN': 894}
# ADV: {'TP': 853, 'FP': 145, 'TN': 23792, 'FN': 223}
# CONJ: {'TP': 719, 'FP': 58, 'TN': 24229, 'FN': 7}
# PRT: {'TP': 566, 'FP': 88, 'TN': 24265, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24236, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24515, 'FN': 85}
# X: {'TP': 13, 'FP': 1, 'TN': 24971, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1025 counts.
# Tag with the most false negative is:  . with 894 counts.
# sentence:       ['In', 'college', 'libraries', ',', '57', 'per', 'cent', 'of', 'the', 'total', 'number', 'of', 'books', 'are', 'owned', 'by', '124', 'of', '1,509', 'institutions', 'surveyed', 'last', 'year', 'by', 'the', 'U.S.', 'Office', 'of', 'Education', '.']
# hidden s:       ['ADP', 'NOUN', 'NOUN', '.', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NUM', 'ADP', 'NUM', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', '.']
# predictions:    ['ADP', 'NOUN', 'NOUN', '.', 'NOUN', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'NOUN', 'VERB', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'NOUN', 'ADP', 'NOUN', 'ADP']
# DET: {'TP': 2955, 'FP': 547, 'TN': 21506, 'FN': 35}
# NOUN: {'TP': 6148, 'FP': 1027, 'TN': 17445, 'FN': 423}
# ADJ: {'TP': 1406, 'FP': 173, 'TN': 22879, 'FN': 585}
# VERB: {'TP': 3141, 'FP': 261, 'TN': 21182, 'FN': 459}
# ADP: {'TP': 3063, 'FP': 462, 'TN': 21405, 'FN': 113}
# .: {'TP': 2178, 'FP': 60, 'TN': 21910, 'FN': 895}
# ADV: {'TP': 853, 'FP': 145, 'TN': 23822, 'FN': 223}
# CONJ: {'TP': 719, 'FP': 58, 'TN': 24259, 'FN': 7}
# PRT: {'TP': 566, 'FP': 88, 'TN': 24295, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24266, 'FN': 11}
# NUM: {'TP': 399, 'FP': 14, 'TN': 24542, 'FN': 88}
# X: {'TP': 13, 'FP': 1, 'TN': 25001, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1027 counts.
# Tag with the most false negative is:  . with 895 counts.
# sentence:       ['And', 'over', '66', 'per', 'cent', 'of', 'the', 'elementary', 'schools', 'with', '150', 'or', 'more', 'pupils', 'do', 'not', 'have', 'any', 'library', 'at', 'all', '.']
# hidden s:       ['CONJ', 'PRT', 'NUM', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', '.']
# predictions:    ['CONJ', 'PRT', 'VERB', 'ADP', 'NOUN', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'NUM', 'CONJ', 'ADJ', 'NOUN', 'VERB', 'ADV', 'VERB', 'DET', 'NOUN', 'ADP', 'PRT', 'CONJ']
# DET: {'TP': 2957, 'FP': 547, 'TN': 21526, 'FN': 35}
# NOUN: {'TP': 6152, 'FP': 1027, 'TN': 17463, 'FN': 423}
# ADJ: {'TP': 1408, 'FP': 173, 'TN': 22899, 'FN': 585}
# VERB: {'TP': 3143, 'FP': 262, 'TN': 21201, 'FN': 459}
# ADP: {'TP': 3067, 'FP': 462, 'TN': 21423, 'FN': 113}
# .: {'TP': 2178, 'FP': 60, 'TN': 21931, 'FN': 896}
# ADV: {'TP': 854, 'FP': 145, 'TN': 23843, 'FN': 223}
# CONJ: {'TP': 721, 'FP': 59, 'TN': 24278, 'FN': 7}
# PRT: {'TP': 568, 'FP': 88, 'TN': 24315, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24288, 'FN': 11}
# NUM: {'TP': 400, 'FP': 14, 'TN': 24562, 'FN': 89}
# X: {'TP': 13, 'FP': 1, 'TN': 25023, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1027 counts.
# Tag with the most false negative is:  . with 896 counts.
# sentence:       ['In', 'every', 'aspect', 'of', 'service', '--', 'to', 'the', 'public', ',', 'to', 'children', 'in', 'schools', ',', 'to', 'colleges', 'and', 'universities', '--', 'the', 'library', 'of', 'today', 'is', 'failing', 'to', 'render', 'vitally', 'needed', 'services', '.']
# hidden s:       ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'ADV', 'VERB', 'NOUN', '.']
# predictions:    ['ADP', 'DET', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'DET', 'NOUN', '.', 'ADP', 'NOUN', 'ADP', 'NOUN', '.', 'ADP', 'NOUN', 'CONJ', 'NOUN', '.', 'DET', 'NOUN', 'ADP', 'NOUN', 'VERB', 'VERB', 'PRT', 'VERB', 'VERB', 'VERB', 'NOUN', 'ADP']
# DET: {'TP': 2960, 'FP': 547, 'TN': 21555, 'FN': 35}
# NOUN: {'TP': 6162, 'FP': 1027, 'TN': 17485, 'FN': 423}
# ADJ: {'TP': 1408, 'FP': 173, 'TN': 22931, 'FN': 585}
# VERB: {'TP': 3147, 'FP': 263, 'TN': 21228, 'FN': 459}
# ADP: {'TP': 3074, 'FP': 463, 'TN': 21447, 'FN': 113}
# .: {'TP': 2182, 'FP': 60, 'TN': 21958, 'FN': 897}
# ADV: {'TP': 854, 'FP': 145, 'TN': 23874, 'FN': 224}
# CONJ: {'TP': 722, 'FP': 59, 'TN': 24309, 'FN': 7}
# PRT: {'TP': 569, 'FP': 88, 'TN': 24346, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24320, 'FN': 11}
# NUM: {'TP': 400, 'FP': 14, 'TN': 24594, 'FN': 89}
# X: {'TP': 13, 'FP': 1, 'TN': 25055, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1027 counts.
# Tag with the most false negative is:  . with 897 counts.
# sentence:       ['Only', 'public', 'understanding', 'and', 'support', 'can', 'provide', 'that', 'service', '.']
# hidden s:       ['ADJ', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'DET', 'NOUN', '.']
# predictions:    ['ADV', 'ADJ', 'NOUN', 'CONJ', 'NOUN', 'VERB', 'VERB', 'ADP', 'NOUN', 'ADV']
# DET: {'TP': 2960, 'FP': 547, 'TN': 21564, 'FN': 36}
# NOUN: {'TP': 6165, 'FP': 1027, 'TN': 17492, 'FN': 423}
# ADJ: {'TP': 1409, 'FP': 173, 'TN': 22939, 'FN': 586}
# VERB: {'TP': 3149, 'FP': 263, 'TN': 21236, 'FN': 459}
# ADP: {'TP': 3074, 'FP': 464, 'TN': 21456, 'FN': 113}
# .: {'TP': 2182, 'FP': 60, 'TN': 21967, 'FN': 898}
# ADV: {'TP': 854, 'FP': 147, 'TN': 23882, 'FN': 224}
# CONJ: {'TP': 723, 'FP': 59, 'TN': 24318, 'FN': 7}
# PRT: {'TP': 569, 'FP': 88, 'TN': 24356, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24330, 'FN': 11}
# NUM: {'TP': 400, 'FP': 14, 'TN': 24604, 'FN': 89}
# X: {'TP': 13, 'FP': 1, 'TN': 25065, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1027 counts.
# Tag with the most false negative is:  . with 898 counts.
# sentence:       ['This', 'is', 'one', 'of', 'the', 'main', 'reasons', 'for', 'National', 'Library', 'Week', ',', 'April', '16-22', ',', 'and', 'for', 'its', 'theme', ':', '``', 'For', 'a', 'richer', ',', 'fuller', 'life', ',', 'read', "''", '!', '!']
# hidden s:       ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NUM', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'ADJ', '.', 'ADJ', 'NOUN', '.', 'VERB', '.', '.', '.']
# predictions:    ['DET', 'VERB', 'NUM', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'ADJ', 'NOUN', 'NOUN', '.', 'NOUN', 'NOUN', '.', 'CONJ', 'ADP', 'DET', 'NOUN', '.', '.', 'ADP', 'DET', 'NOUN', '.', 'DET', 'NOUN', '.', 'VERB', '.', '.', 'DET']
# DET: {'TP': 2964, 'FP': 549, 'TN': 21590, 'FN': 36}
# NOUN: {'TP': 6171, 'FP': 1029, 'TN': 17516, 'FN': 423}
# ADJ: {'TP': 1411, 'FP': 173, 'TN': 22967, 'FN': 588}
# VERB: {'TP': 3151, 'FP': 263, 'TN': 21266, 'FN': 459}
# ADP: {'TP': 3078, 'FP': 464, 'TN': 21484, 'FN': 113}
# .: {'TP': 2190, 'FP': 60, 'TN': 21990, 'FN': 899}
# ADV: {'TP': 854, 'FP': 147, 'TN': 23914, 'FN': 224}
# CONJ: {'TP': 724, 'FP': 59, 'TN': 24349, 'FN': 7}
# PRT: {'TP': 569, 'FP': 88, 'TN': 24388, 'FN': 94}
# PRON: {'TP': 641, 'FP': 125, 'TN': 24362, 'FN': 11}
# NUM: {'TP': 401, 'FP': 14, 'TN': 24634, 'FN': 90}
# X: {'TP': 13, 'FP': 1, 'TN': 25097, 'FN': 28}
#
# Tag with the most false positives is: NOUN with 1029 counts.
# Tag with the most false negative is:  . with 899 counts.
#
# model got 22167 samples correct out of 25139
# accuracy: 0.8817773181113011

# %%
import numpy as np

def viterbi(observations, states, start_prob, trans_prob, emit_prob):
    """
    Perform the Viterbi algorithm to find the most probable sequence of hidden states.

    Args:
        observations (list): A list of observed events (e.g., ['Walk', 'Shop', 'Clean']).
        states (list): A list of possible hidden states (e.g., ['Rainy', 'Sunny']).
        start_prob (dict): A dictionary representing the start probability for each state (e.g., {'Rainy': 0.6, 'Sunny': 0.4}).
        trans_prob (dict): A dictionary of dictionaries representing the transition probability from each state to every other state
                           (e.g., {'Rainy': {'Rainy': 0.7, 'Sunny': 0.3}, 'Sunny': {'Rainy': 0.4, 'Sunny': 0.6}}).
        emit_prob (dict): A dictionary of dictionaries representing the emission probability of each observation from each state
                          (e.g., {'Rainy': {'Walk': 0.1, 'Shop': 0.4, 'Clean': 0.5}, 'Sunny': {'Walk': 0.6, 'Shop': 0.3, 'Clean': 0.1}}).

    Returns:
        tuple: The most probable sequence of hidden states and its probability.
    """
    N = len(states)
    T = len(observations)

    # Map states and observations to indices
    state_index = {state: idx for idx, state in enumerate(states)}
    obs_index = {obs: idx for idx, obs in enumerate(emit_prob[states[0]].keys())}

    # Initialize the Viterbi table and backpointer table
    viterbi = np.zeros((N, T))
    backpointer = np.zeros((N, T), dtype=int)

    # Convert start_prob, trans_prob, and emit_prob to numpy arrays
    start_prob = np.array([start_prob[state] for state in states])
    trans_prob = np.array([[trans_prob[states[i]][states[j]] for j in range(N)] for i in range(N)])
    emit_prob = np.array([[emit_prob[state][obs] for obs in observations] for state in states])

    # Initialization step
    ''' Your Code Here '''

    # Recursion step
    for t in range(1, T):
        for s in range(N):
            ''' Your Code Here '''

    # Termination step
    ''' Your Code Here '''

    # Path backtracking
    ''' Your Code Here '''

    return bestpath, bestpathprob
